# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
import keras.layers as layers
from keras.models import Model, load_model
from keras.engine import Layer
from keras.utils import to_categorical 
from sklearn.metrics import precision_recall_fscore_support
import random
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Preprocessing

# %%
df = pd.read_csv('Data.csv', encoding = "ISO-8859-1")
#df = df.drop(columns=df.columns[:9].append(df.columns[11:]))
#df = df.groupby(['Winner', 'Loser']).size().reset_index(name='counts')

# %%
df
# Out:
#        ATP        Location                          Tournament        Date  \
# 0        1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 1        1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 2        1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 3        1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 4        1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 5        1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 6        1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 7        1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 8        1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 9        1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 10       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 11       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 12       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 13       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 14       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 15       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 16       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 17       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 18       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 19       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 20       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 21       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 22       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 23       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 24       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 25       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 26       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 27       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 28       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# 29       1        Adelaide  Australian Hardcourt Championships   3/01/2000
# ...    ...             ...                                 ...         ...
# 46622   53            Metz                     Open de Moselle  24/09/2016
# 46623   53            Metz                     Open de Moselle  24/09/2016
# 46624   53            Metz                     Open de Moselle  25/09/2016
# 46625   54  St. Petersburg                 St. Petersburg Open  19/09/2016
# 46626   54  St. Petersburg                 St. Petersburg Open  19/09/2016
# 46627   54  St. Petersburg                 St. Petersburg Open  19/09/2016
# 46628   54  St. Petersburg                 St. Petersburg Open  20/09/2016
# 46629   54  St. Petersburg                 St. Petersburg Open  20/09/2016
# 46630   54  St. Petersburg                 St. Petersburg Open  20/09/2016
# 46631   54  St. Petersburg                 St. Petersburg Open  20/09/2016
# 46632   54  St. Petersburg                 St. Petersburg Open  21/09/2016
# 46633   54  St. Petersburg                 St. Petersburg Open  21/09/2016
# 46634   54  St. Petersburg                 St. Petersburg Open  21/09/2016
# 46635   54  St. Petersburg                 St. Petersburg Open  21/09/2016
# 46636   54  St. Petersburg                 St. Petersburg Open  21/09/2016
# 46637   54  St. Petersburg                 St. Petersburg Open  21/09/2016
# 46638   54  St. Petersburg                 St. Petersburg Open  21/09/2016
# 46639   54  St. Petersburg                 St. Petersburg Open  22/09/2016
# 46640   54  St. Petersburg                 St. Petersburg Open  22/09/2016
# 46641   54  St. Petersburg                 St. Petersburg Open  22/09/2016
# 46642   54  St. Petersburg                 St. Petersburg Open  22/09/2016
# 46643   54  St. Petersburg                 St. Petersburg Open  22/09/2016
# 46644   54  St. Petersburg                 St. Petersburg Open  22/09/2016
# 46645   54  St. Petersburg                 St. Petersburg Open  23/09/2016
# 46646   54  St. Petersburg                 St. Petersburg Open  23/09/2016
# 46647   54  St. Petersburg                 St. Petersburg Open  23/09/2016
# 46648   54  St. Petersburg                 St. Petersburg Open  23/09/2016
# 46649   54  St. Petersburg                 St. Petersburg Open  24/09/2016
# 46650   54  St. Petersburg                 St. Petersburg Open  24/09/2016
# 46651   54  St. Petersburg                 St. Petersburg Open  25/09/2016
#
#               Series    Court Surface          Round  Best of  \
# 0      International  Outdoor    Hard      1st Round        3
# 1      International  Outdoor    Hard      1st Round        3
# 2      International  Outdoor    Hard      1st Round        3
# 3      International  Outdoor    Hard      1st Round        3
# 4      International  Outdoor    Hard      1st Round        3
# 5      International  Outdoor    Hard      1st Round        3
# 6      International  Outdoor    Hard      1st Round        3
# 7      International  Outdoor    Hard      1st Round        3
# 8      International  Outdoor    Hard      1st Round        3
# 9      International  Outdoor    Hard      1st Round        3
# 10     International  Outdoor    Hard      1st Round        3
# 11     International  Outdoor    Hard      1st Round        3
# 12     International  Outdoor    Hard      1st Round        3
# 13     International  Outdoor    Hard      1st Round        3
# 14     International  Outdoor    Hard      1st Round        3
# 15     International  Outdoor    Hard      1st Round        3
# 16     International  Outdoor    Hard      2nd Round        3
# 17     International  Outdoor    Hard      2nd Round        3
# 18     International  Outdoor    Hard      2nd Round        3
# 19     International  Outdoor    Hard      2nd Round        3
# 20     International  Outdoor    Hard      2nd Round        3
# 21     International  Outdoor    Hard      2nd Round        3
# 22     International  Outdoor    Hard      2nd Round        3
# 23     International  Outdoor    Hard      2nd Round        3
# 24     International  Outdoor    Hard  Quarterfinals        3
# 25     International  Outdoor    Hard  Quarterfinals        3
# 26     International  Outdoor    Hard  Quarterfinals        3
# 27     International  Outdoor    Hard  Quarterfinals        3
# 28     International  Outdoor    Hard     Semifinals        3
# 29     International  Outdoor    Hard     Semifinals        3
# ...              ...      ...     ...            ...      ...
# 46622         ATP250   Indoor    Hard     Semifinals        3
# 46623         ATP250   Indoor    Hard     Semifinals        3
# 46624         ATP250   Indoor    Hard      The Final        3
# 46625         ATP250   Indoor    Hard      1st Round        3
# 46626         ATP250   Indoor    Hard      1st Round        3
# 46627         ATP250   Indoor    Hard      1st Round        3
# 46628         ATP250   Indoor    Hard      1st Round        3
# 46629         ATP250   Indoor    Hard      1st Round        3
# 46630         ATP250   Indoor    Hard      1st Round        3
# 46631         ATP250   Indoor    Hard      1st Round        3
# 46632         ATP250   Indoor    Hard      1st Round        3
# 46633         ATP250   Indoor    Hard      1st Round        3
# 46634         ATP250   Indoor    Hard      1st Round        3
# 46635         ATP250   Indoor    Hard      1st Round        3
# 46636         ATP250   Indoor    Hard      1st Round        3
# 46637         ATP250   Indoor    Hard      2nd Round        3
# 46638         ATP250   Indoor    Hard      2nd Round        3
# 46639         ATP250   Indoor    Hard      2nd Round        3
# 46640         ATP250   Indoor    Hard      2nd Round        3
# 46641         ATP250   Indoor    Hard      2nd Round        3
# 46642         ATP250   Indoor    Hard      2nd Round        3
# 46643         ATP250   Indoor    Hard      2nd Round        3
# 46644         ATP250   Indoor    Hard      2nd Round        3
# 46645         ATP250   Indoor    Hard  Quarterfinals        3
# 46646         ATP250   Indoor    Hard  Quarterfinals        3
# 46647         ATP250   Indoor    Hard  Quarterfinals        3
# 46648         ATP250   Indoor    Hard  Quarterfinals        3
# 46649         ATP250   Indoor    Hard     Semifinals        3
# 46650         ATP250   Indoor    Hard     Semifinals        3
# 46651         ATP250   Indoor    Hard      The Final        3
#
#                  Winner  ... UBW UBL   LBW   LBL  SJW  SJL  MaxW  MaxL  AvgW  \
# 0            Dosedel S.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 1            Enqvist T.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 2             Escude N.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 3            Federer R.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 4           Fromberg R.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 5          Gambill J.M.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 6           Grosjean S.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 7             Henman T.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 8             Hewitt L.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 9            Lisnard J.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 10            Martin A.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 11            Norman M.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 12          Petrovic D.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 13           Sekulov J.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 14       Stoltenberg J.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 15             Vinck C.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 16           Enqvist T.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 17            Escude N.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 18          Grosjean S.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 19            Henman T.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 20            Hewitt L.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 21            Martin A.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 22            Norman M.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 23       Stoltenberg J.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 24           Enqvist T.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 25            Escude N.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 26            Hewitt L.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 27            Norman M.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 28           Enqvist T.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# 29            Hewitt L.  ... NaN NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN
# ...                 ...  ...  ..  ..   ...   ...  ...  ...   ...   ...   ...
# 46622          Thiem D.  ... NaN NaN  1.53  2.50  NaN  NaN  1.57  2.65  1.51
# 46623        Pouille L.  ... NaN NaN  2.75  1.44  NaN  NaN  2.86  1.52  2.67
# 46624        Pouille L.  ... NaN NaN  2.50  1.53  NaN  NaN  2.55  1.65  2.39
# 46625       Berankis R.  ... NaN NaN  2.38  1.57  NaN  NaN  2.38  1.71  2.23
# 46626          Rosol L.  ... NaN NaN  1.50  2.62  NaN  NaN  1.53  2.75  1.48
# 46627         Zverev A.  ... NaN NaN  1.53  2.50  NaN  NaN  1.62  2.60  1.55
# 46628      Sidorenko A.  ... NaN NaN  3.40  1.33  NaN  NaN  3.45  1.38  3.23
# 46629        Lorenzi P.  ... NaN NaN  2.62  1.50  NaN  NaN  2.75  1.54  2.62
# 46630       Medvedev D.  ... NaN NaN  1.20  4.50  NaN  NaN  1.23  4.75  1.20
# 46631        Lajovic D.  ... NaN NaN  2.75  1.44  NaN  NaN  3.15  1.44  2.88
# 46632         Rublev A.  ... NaN NaN  2.25  1.62  NaN  NaN  2.53  1.63  2.36
# 46633          Sousa J.  ... NaN NaN  1.53  2.50  NaN  NaN  1.56  2.75  1.48
# 46634        Youzhny M.  ... NaN NaN  1.80  2.00  NaN  NaN  2.01  2.00  1.85
# 46635        Troicki V.  ... NaN NaN  1.25  4.00  NaN  NaN  1.29  4.30  1.24
# 46636     Kuznetsov An.  ... NaN NaN  1.44  2.75  NaN  NaN  1.45  3.05  1.41
# 46637       Wawrinka S.  ... NaN NaN  1.20  4.50  NaN  NaN  1.30  4.50  1.25
# 46638  Bautista Agut R.  ... NaN NaN  1.17  5.00  NaN  NaN  1.20  5.28  1.18
# 46639          Sousa J.  ... NaN NaN  1.44  2.75  NaN  NaN  1.55  2.80  1.47
# 46640        Lorenzi P.  ... NaN NaN  1.44  2.75  NaN  NaN  1.47  3.05  1.40
# 46641        Troicki V.  ... NaN NaN  1.40  3.00  NaN  NaN  1.43  3.25  1.37
# 46642        Berdych T.  ... NaN NaN  1.40  3.00  NaN  NaN  1.43  3.15  1.38
# 46643         Zverev A.  ... NaN NaN  1.36  3.25  NaN  NaN  1.39  3.75  1.32
# 46644        Youzhny M.  ... NaN NaN  5.00  1.17  NaN  NaN  5.96  1.18  5.23
# 46645        Berdych T.  ... NaN NaN  1.17  5.00  NaN  NaN  1.20  5.80  1.16
# 46646  Bautista Agut R.  ... NaN NaN  1.36  3.25  NaN  NaN  1.40  3.45  1.36
# 46647         Zverev A.  ... NaN NaN  1.57  2.38  NaN  NaN  1.66  2.45  1.60
# 46648       Wawrinka S.  ... NaN NaN  1.22  4.33  NaN  NaN  1.24  4.91  1.21
# 46649         Zverev A.  ... NaN NaN  2.38  1.57  NaN  NaN  3.12  1.57  2.68
# 46650       Wawrinka S.  ... NaN NaN  1.33  3.40  NaN  NaN  1.41  3.80  1.31
# 46651         Zverev A.  ... NaN NaN  3.30  1.33  NaN  NaN  3.58  1.36  3.36
#
#        AvgL
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
# ...     ...
# 46622  2.51
# 46623  1.46
# 46624  1.56
# 46625  1.63
# 46626  2.59
# 46627  2.41
# 46628  1.33
# 46629  1.47
# 46630  4.36
# 46631  1.40
# 46632  1.57
# 46633  2.59
# 46634  1.92
# 46635  3.93
# 46636  2.81
# 46637  3.87
# 46638  4.73
# 46639  2.63
# 46640  2.86
# 46641  3.04
# 46642  2.98
# 46643  3.32
# 46644  1.15
# 46645  5.02
# 46646  3.11
# 46647  2.30
# 46648  4.34
# 46649  1.46
# 46650  3.40
# 46651  1.31
#
# [46652 rows x 54 columns]

# %%
def win_rate(w, l, df, c):
    if df[(df.Winner == l) & (df.Loser == w)].empty:
        return 1
    else:
        return c/(c+ df[(df.Winner == l) & (df.Loser == w)]['counts'])
df['win_rate'] = df.apply(lambda row: win_rate(row.Winner, row.Loser, df, row.counts), axis=1)

# %%
def delist(x):
    if type(x) == np.ndarray:
        return x[0]
    else:
        return x
df['win_rate'] = df.win_rate.apply(lambda x: delist(x))

# %%
df['check_string'] = df.apply(lambda row: ''.join(sorted([row['Winner'], row['Loser']])), axis=1)
df = df.drop_duplicates('check_string', keep='last')
df['last_win'] = df.apply(lambda x: 0, axis=1)
df['meetings'] = df.apply(lambda x: np.round(x.counts/x.win_rate), axis=1)

# %%
def swapper(row):
    if random.choice([True,False]):
        x = row['Winner']
        row['Winner'] = row['Loser']
        row['Loser'] = x
        row['last_win'] = 1
        row['win_rate'] = 1 - row['win_rate']
    return row
df = df.apply(swapper, axis=1)
df = df.rename(columns={'Winner': 'player_0', 'Loser':'player_1'})
df = df.drop(columns=['check_string', 'counts'])

# %%
df.head()
# Out:
#        player_0     player_1  win_rate  last_win  meetings
# 0      Hajek J.  Ulihrach B.       1.0         0       1.0
# 1     Dupuis A.      Abel M.       0.0         1       1.0
# 2  Heuberger I.      Abel M.       0.0         1       1.0
# 5    Acasuso J.     Arazi H.       1.0         0       1.0
# 6  Bachinger M.   Acasuso J.       0.0         1       1.0

# %%
df.to_csv('tennis_h2h.csv', index=False)

# %%
players, counts = np.unique(np.concatenate((df.player_0.values,df.player_1.values)), return_counts=True)

# %%
def win_rate_cat(win_rate):
    if win_rate > 0.65:
        return 0
    elif win_rate < 0.34:
        return 1
    else:
        return 2
df['win_rate_cat'] = df.win_rate.apply(lambda x: win_rate_cat(x))

# %% [markdown]
# # Modeling

# %%
def build_model(): 
    player_1 = layers.Input(shape=(1,))
    player_2 = layers.Input(shape=(1,))
    emb_layer = layers.Embedding(num_players, 5)
    player_1_embedding = emb_layer(player_1)
    player_2_embedding = emb_layer(player_2)
    player_1_flat = layers.Flatten()(player_1_embedding)
    player_2_flat = layers.Flatten()(player_2_embedding)
    cl_concat = layers.Concatenate()([player_1_flat, player_2_flat])
    cl_dense = layers.Dense(100, activation='relu')(cl_concat)
    cl_dense1 = layers.Dense(20, activation='relu')(cl_dense)
    pred = layers.Dense(3, activation="softmax")(cl_dense1)
    model = Model([player_1, player_2], pred)
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    model.summary()
    return model

# %%
freq = np.empty((5,3))
samp = np.empty((5,3))
for idx, i in enumerate(range(5)):
    #freq_players = np.squeeze(players[np.argwhere(counts>i)])
    #freq_df = df[(df.player_0.isin(freq_players)) & (df.player_1.isin(freq_players))]
    freq_df = df[df.meetings>i]
    for j in range(3):
        sample_df = df.sample(len(freq_df))

        ids = pd.factorize(np.concatenate((freq_df.player_0, freq_df.player_1)))[0]
        freq_df['p1'] =  ids[:len(freq_df)]
        freq_df['p2'] = ids[len(freq_df):]
        num_players = np.max(np.concatenate((freq_df.p1.values, freq_df.p2.values))) + 1

        train_player_1, test_player_1, train_player_2,test_player_2, train_labels, test_labels = train_test_split(freq_df['p1'], freq_df['p2'], to_categorical(freq_df['win_rate_cat']), test_size=0.1)
        model = None
        model = build_model()
        history = model.fit([train_player_1, train_player_2],
                  train_labels,
                 validation_data=([test_player_1, test_player_2], test_labels),
                  epochs=5,
                  batch_size=32
                 )
        preds = model.predict([test_player_1, test_player_2])
        freq[idx, j] = precision_recall_fscore_support(np.argmax(test_labels,axis=1), np.argmax(preds, axis=1), average='macro')[2]

        ids = pd.factorize(np.concatenate((sample_df.player_0, sample_df.player_1)))[0]
        sample_df['p1'] =  ids[:len(sample_df)]
        sample_df['p2'] = ids[len(sample_df):]
        num_players = np.max(np.concatenate((sample_df.p1.values, sample_df.p2.values))) + 1

        train_player_1, test_player_1, train_player_2,test_player_2, train_labels, test_labels = train_test_split(sample_df['p1'], sample_df['p2'], to_categorical(sample_df['win_rate_cat']), test_size=0.1)
        model = None
        model = build_model()
        history = model.fit([train_player_1, train_player_2],
                  train_labels,
                 validation_data=([test_player_1, test_player_2], test_labels),
                  epochs=5,
                  batch_size=32
                 )
        preds = model.predict([test_player_1, test_player_2])
        samp[idx, j] = precision_recall_fscore_support(np.argmax(test_labels,axis=1), np.argmax(preds, axis=1), average='macro')[2]
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_71 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_72 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# embedding_36 (Embedding)        (None, 1, 5)         6935        input_71[0][0]
#                                                                  input_72[0][0]
# __________________________________________________________________________________________________
# flatten_71 (Flatten)            (None, 5)            0           embedding_36[0][0]
# __________________________________________________________________________________________________
# flatten_72 (Flatten)            (None, 5)            0           embedding_36[1][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 10)           0           flatten_71[0][0]
#                                                                  flatten_72[0][0]
# __________________________________________________________________________________________________
# dense_106 (Dense)               (None, 100)          1100        concatenate_36[0][0]
# __________________________________________________________________________________________________
# dense_107 (Dense)               (None, 20)           2020        dense_106[0][0]
# __________________________________________________________________________________________________
# dense_108 (Dense)               (None, 3)            63          dense_107[0][0]
# ==================================================================================================
# Total params: 10,118
# Trainable params: 10,118
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 23012 samples, validate on 2557 samples
# Epoch 1/5
# 23012/23012 [==============================] - 4s 176us/step - loss: 0.8931 - val_loss: 0.8362
# Epoch 2/5
# 23012/23012 [==============================] - 1s 46us/step - loss: 0.8219 - val_loss: 0.8329
# Epoch 3/5
# 23012/23012 [==============================] - 1s 42us/step - loss: 0.8062 - val_loss: 0.8314
# Epoch 4/5
# 23012/23012 [==============================] - 1s 41us/step - loss: 0.7943 - val_loss: 0.8401
# Epoch 5/5
# 23012/23012 [==============================] - 1s 45us/step - loss: 0.7840 - val_loss: 0.8486
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_73 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_74 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# embedding_37 (Embedding)        (None, 1, 5)         6935        input_73[0][0]
#                                                                  input_74[0][0]
# __________________________________________________________________________________________________
# flatten_73 (Flatten)            (None, 5)            0           embedding_37[0][0]
# __________________________________________________________________________________________________
# flatten_74 (Flatten)            (None, 5)            0           embedding_37[1][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 10)           0           flatten_73[0][0]
#                                                                  flatten_74[0][0]
# __________________________________________________________________________________________________
# dense_109 (Dense)               (None, 100)          1100        concatenate_37[0][0]
# __________________________________________________________________________________________________
# dense_110 (Dense)               (None, 20)           2020        dense_109[0][0]
# __________________________________________________________________________________________________
# dense_111 (Dense)               (None, 3)            63          dense_110[0][0]
# ==================================================================================================
# Total params: 10,118
# Trainable params: 10,118
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 23012 samples, validate on 2557 samples
# Epoch 1/5
# 23012/23012 [==============================] - 3s 138us/step - loss: 0.9097 - val_loss: 0.8323
# Epoch 2/5
# 23012/23012 [==============================] - 1s 44us/step - loss: 0.8211 - val_loss: 0.8180
# Epoch 3/5
# 23012/23012 [==============================] - 1s 43us/step - loss: 0.8016 - val_loss: 0.8175
# Epoch 4/5
# 23012/23012 [==============================] - 1s 50us/step - loss: 0.7897 - val_loss: 0.8323
# Epoch 5/5
# 23012/23012 [==============================] - 1s 48us/step - loss: 0.7801 - val_loss: 0.8259
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_75 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_76 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# embedding_38 (Embedding)        (None, 1, 5)         6935        input_75[0][0]
#                                                                  input_76[0][0]
# __________________________________________________________________________________________________
# flatten_75 (Flatten)            (None, 5)            0           embedding_38[0][0]
# __________________________________________________________________________________________________
# flatten_76 (Flatten)            (None, 5)            0           embedding_38[1][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 10)           0           flatten_75[0][0]
#                                                                  flatten_76[0][0]
# __________________________________________________________________________________________________
# dense_112 (Dense)               (None, 100)          1100        concatenate_38[0][0]
# __________________________________________________________________________________________________
# dense_113 (Dense)               (None, 20)           2020        dense_112[0][0]
# __________________________________________________________________________________________________
# dense_114 (Dense)               (None, 3)            63          dense_113[0][0]
# ==================================================================================================
# Total params: 10,118
# Trainable params: 10,118
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 23012 samples, validate on 2557 samples
# Epoch 1/5
# 23012/23012 [==============================] - 3s 147us/step - loss: 0.8861 - val_loss: 0.8469
# Epoch 2/5
# 23012/23012 [==============================] - 1s 55us/step - loss: 0.8164 - val_loss: 0.8488
# Epoch 3/5
# 23012/23012 [==============================] - 1s 51us/step - loss: 0.7996 - val_loss: 0.8490
# Epoch 4/5
# 23012/23012 [==============================] - 1s 47us/step - loss: 0.7887 - val_loss: 0.8565
# Epoch 5/5
# 23012/23012 [==============================] - 1s 41us/step - loss: 0.7787 - val_loss: 0.8671
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_77 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_78 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# embedding_39 (Embedding)        (None, 1, 5)         6935        input_77[0][0]
#                                                                  input_78[0][0]
# __________________________________________________________________________________________________
# flatten_77 (Flatten)            (None, 5)            0           embedding_39[0][0]
# __________________________________________________________________________________________________
# flatten_78 (Flatten)            (None, 5)            0           embedding_39[1][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 10)           0           flatten_77[0][0]
#                                                                  flatten_78[0][0]
# __________________________________________________________________________________________________
# dense_115 (Dense)               (None, 100)          1100        concatenate_39[0][0]
# __________________________________________________________________________________________________
# dense_116 (Dense)               (None, 20)           2020        dense_115[0][0]
# __________________________________________________________________________________________________
# dense_117 (Dense)               (None, 3)            63          dense_116[0][0]
# ==================================================================================================
# Total params: 10,118
# Trainable params: 10,118
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 23012 samples, validate on 2557 samples
# Epoch 1/5
# 23012/23012 [==============================] - 3s 148us/step - loss: 0.9003 - val_loss: 0.8431
# Epoch 2/5
# 23012/23012 [==============================] - 1s 50us/step - loss: 0.8192 - val_loss: 0.8367
# Epoch 3/5
# 23012/23012 [==============================] - 1s 53us/step - loss: 0.8026 - val_loss: 0.8392
# Epoch 4/5
# 23012/23012 [==============================] - 1s 50us/step - loss: 0.7904 - val_loss: 0.8431
# Epoch 5/5
# 23012/23012 [==============================] - 1s 47us/step - loss: 0.7808 - val_loss: 0.8537
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_79 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_80 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# embedding_40 (Embedding)        (None, 1, 5)         6935        input_79[0][0]
#                                                                  input_80[0][0]
# __________________________________________________________________________________________________
# flatten_79 (Flatten)            (None, 5)            0           embedding_40[0][0]
# __________________________________________________________________________________________________
# flatten_80 (Flatten)            (None, 5)            0           embedding_40[1][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 10)           0           flatten_79[0][0]
#                                                                  flatten_80[0][0]
# __________________________________________________________________________________________________
# dense_118 (Dense)               (None, 100)          1100        concatenate_40[0][0]
# __________________________________________________________________________________________________
# dense_119 (Dense)               (None, 20)           2020        dense_118[0][0]
# __________________________________________________________________________________________________
# dense_120 (Dense)               (None, 3)            63          dense_119[0][0]
# ==================================================================================================
# Total params: 10,118
# Trainable params: 10,118
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 23012 samples, validate on 2557 samples
# Epoch 1/5
# 23012/23012 [==============================] - 3s 145us/step - loss: 0.8917 - val_loss: 0.8501
# Epoch 2/5
# 23012/23012 [==============================] - 1s 44us/step - loss: 0.8190 - val_loss: 0.8445
# Epoch 3/5
# 23012/23012 [==============================] - 1s 43us/step - loss: 0.8008 - val_loss: 0.8481
# Epoch 4/5
# 23012/23012 [==============================] - 1s 45us/step - loss: 0.7888 - val_loss: 0.8516
# Epoch 5/5
# 23012/23012 [==============================] - 1s 44us/step - loss: 0.7783 - val_loss: 0.8484
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_81 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_82 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# embedding_41 (Embedding)        (None, 1, 5)         6935        input_81[0][0]
#                                                                  input_82[0][0]
# __________________________________________________________________________________________________
# flatten_81 (Flatten)            (None, 5)            0           embedding_41[0][0]
# __________________________________________________________________________________________________
# flatten_82 (Flatten)            (None, 5)            0           embedding_41[1][0]
# __________________________________________________________________________________________________
# concatenate_41 (Concatenate)    (None, 10)           0           flatten_81[0][0]
#                                                                  flatten_82[0][0]
# __________________________________________________________________________________________________
# dense_121 (Dense)               (None, 100)          1100        concatenate_41[0][0]
# __________________________________________________________________________________________________
# dense_122 (Dense)               (None, 20)           2020        dense_121[0][0]
# __________________________________________________________________________________________________
# dense_123 (Dense)               (None, 3)            63          dense_122[0][0]
# ==================================================================================================
# Total params: 10,118
# Trainable params: 10,118
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 23012 samples, validate on 2557 samples
# Epoch 1/5
# 23012/23012 [==============================] - 3s 146us/step - loss: 0.8982 - val_loss: 0.8498
# Epoch 2/5
# 23012/23012 [==============================] - 1s 45us/step - loss: 0.8179 - val_loss: 0.8425
# Epoch 3/5
# 23012/23012 [==============================] - 1s 46us/step - loss: 0.8015 - val_loss: 0.8442
# Epoch 4/5
# 23012/23012 [==============================] - 1s 44us/step - loss: 0.7897 - val_loss: 0.8527
# Epoch 5/5
# 23012/23012 [==============================] - 1s 45us/step - loss: 0.7774 - val_loss: 0.8677
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_83 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_84 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# embedding_42 (Embedding)        (None, 1, 5)         2655        input_83[0][0]
#                                                                  input_84[0][0]
# __________________________________________________________________________________________________
# flatten_83 (Flatten)            (None, 5)            0           embedding_42[0][0]
# __________________________________________________________________________________________________
# flatten_84 (Flatten)            (None, 5)            0           embedding_42[1][0]
# __________________________________________________________________________________________________
# concatenate_42 (Concatenate)    (None, 10)           0           flatten_83[0][0]
#                                                                  flatten_84[0][0]
# __________________________________________________________________________________________________
# dense_124 (Dense)               (None, 100)          1100        concatenate_42[0][0]
# __________________________________________________________________________________________________
# dense_125 (Dense)               (None, 20)           2020        dense_124[0][0]
# __________________________________________________________________________________________________
# dense_126 (Dense)               (None, 3)            63          dense_125[0][0]
# ==================================================================================================
# Total params: 5,838
# Trainable params: 5,838
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 8343 samples, validate on 927 samples
# Epoch 1/5
# 8343/8343 [==============================] - 3s 337us/step - loss: 1.0445 - val_loss: 0.9454
# Epoch 2/5
# 8343/8343 [==============================] - 0s 44us/step - loss: 0.9478 - val_loss: 0.9387
# Epoch 3/5
# 8343/8343 [==============================] - 0s 47us/step - loss: 0.9313 - val_loss: 0.9353
# Epoch 4/5
# 8343/8343 [==============================] - 0s 48us/step - loss: 0.9221 - val_loss: 0.9430
# Epoch 5/5
# 8343/8343 [==============================] - 0s 46us/step - loss: 0.9111 - val_loss: 0.9420
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_85 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_86 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# embedding_43 (Embedding)        (None, 1, 5)         5365        input_85[0][0]
#                                                                  input_86[0][0]
# __________________________________________________________________________________________________
# flatten_85 (Flatten)            (None, 5)            0           embedding_43[0][0]
# __________________________________________________________________________________________________
# flatten_86 (Flatten)            (None, 5)            0           embedding_43[1][0]
# __________________________________________________________________________________________________
# concatenate_43 (Concatenate)    (None, 10)           0           flatten_85[0][0]
#                                                                  flatten_86[0][0]
# __________________________________________________________________________________________________
# dense_127 (Dense)               (None, 100)          1100        concatenate_43[0][0]
# __________________________________________________________________________________________________
# dense_128 (Dense)               (None, 20)           2020        dense_127[0][0]
# __________________________________________________________________________________________________
# dense_129 (Dense)               (None, 3)            63          dense_128[0][0]
# ==================================================================================================
# Total params: 8,548
# Trainable params: 8,548
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 8343 samples, validate on 927 samples
# Epoch 1/5
# 8343/8343 [==============================] - 3s 355us/step - loss: 0.9632 - val_loss: 0.9234
# Epoch 2/5
# 8343/8343 [==============================] - 0s 44us/step - loss: 0.8390 - val_loss: 0.8947
# Epoch 3/5
# 8343/8343 [==============================] - 0s 46us/step - loss: 0.7745 - val_loss: 0.9104
# Epoch 4/5
# 8343/8343 [==============================] - 0s 51us/step - loss: 0.7457 - val_loss: 0.9214
# Epoch 5/5
# 8343/8343 [==============================] - 1s 61us/step - loss: 0.7235 - val_loss: 0.9322
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_87 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_88 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# embedding_44 (Embedding)        (None, 1, 5)         2655        input_87[0][0]
#                                                                  input_88[0][0]
# __________________________________________________________________________________________________
# flatten_87 (Flatten)            (None, 5)            0           embedding_44[0][0]
# __________________________________________________________________________________________________
# flatten_88 (Flatten)            (None, 5)            0           embedding_44[1][0]
# __________________________________________________________________________________________________
# concatenate_44 (Concatenate)    (None, 10)           0           flatten_87[0][0]
#                                                                  flatten_88[0][0]
# __________________________________________________________________________________________________
# dense_130 (Dense)               (None, 100)          1100        concatenate_44[0][0]
# __________________________________________________________________________________________________
# dense_131 (Dense)               (None, 20)           2020        dense_130[0][0]
# __________________________________________________________________________________________________
# dense_132 (Dense)               (None, 3)            63          dense_131[0][0]
# ==================================================================================================
# Total params: 5,838
# Trainable params: 5,838
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 8343 samples, validate on 927 samples
# Epoch 1/5
# 8343/8343 [==============================] - 3s 355us/step - loss: 1.0446 - val_loss: 0.9859
# Epoch 2/5
# 8343/8343 [==============================] - 0s 54us/step - loss: 0.9430 - val_loss: 0.9616
# Epoch 3/5
# 8343/8343 [==============================] - 0s 47us/step - loss: 0.9250 - val_loss: 0.9653
# Epoch 4/5
# 8343/8343 [==============================] - 0s 49us/step - loss: 0.9155 - val_loss: 0.9691
# Epoch 5/5
# 8343/8343 [==============================] - 0s 44us/step - loss: 0.9047 - val_loss: 0.9798
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_89 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_90 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# embedding_45 (Embedding)        (None, 1, 5)         5185        input_89[0][0]
#                                                                  input_90[0][0]
# __________________________________________________________________________________________________
# flatten_89 (Flatten)            (None, 5)            0           embedding_45[0][0]
# __________________________________________________________________________________________________
# flatten_90 (Flatten)            (None, 5)            0           embedding_45[1][0]
# __________________________________________________________________________________________________
# concatenate_45 (Concatenate)    (None, 10)           0           flatten_89[0][0]
#                                                                  flatten_90[0][0]
# __________________________________________________________________________________________________
# dense_133 (Dense)               (None, 100)          1100        concatenate_45[0][0]
# __________________________________________________________________________________________________
# dense_134 (Dense)               (None, 20)           2020        dense_133[0][0]
# __________________________________________________________________________________________________
# dense_135 (Dense)               (None, 3)            63          dense_134[0][0]
# ==================================================================================================
# Total params: 8,368
# Trainable params: 8,368
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 8343 samples, validate on 927 samples
# Epoch 1/5
# 8343/8343 [==============================] - 3s 354us/step - loss: 0.9573 - val_loss: 0.8842
# Epoch 2/5
# 8343/8343 [==============================] - 0s 50us/step - loss: 0.8506 - val_loss: 0.8727
# Epoch 3/5
# 8343/8343 [==============================] - 0s 50us/step - loss: 0.8124 - val_loss: 0.8746
# Epoch 4/5
# 8343/8343 [==============================] - 0s 50us/step - loss: 0.7860 - val_loss: 0.9047
# Epoch 5/5
# 8343/8343 [==============================] - 0s 49us/step - loss: 0.7647 - val_loss: 0.9033
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_91 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_92 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# embedding_46 (Embedding)        (None, 1, 5)         2655        input_91[0][0]
#                                                                  input_92[0][0]
# __________________________________________________________________________________________________
# flatten_91 (Flatten)            (None, 5)            0           embedding_46[0][0]
# __________________________________________________________________________________________________
# flatten_92 (Flatten)            (None, 5)            0           embedding_46[1][0]
# __________________________________________________________________________________________________
# concatenate_46 (Concatenate)    (None, 10)           0           flatten_91[0][0]
#                                                                  flatten_92[0][0]
# __________________________________________________________________________________________________
# dense_136 (Dense)               (None, 100)          1100        concatenate_46[0][0]
# __________________________________________________________________________________________________
# dense_137 (Dense)               (None, 20)           2020        dense_136[0][0]
# __________________________________________________________________________________________________
# dense_138 (Dense)               (None, 3)            63          dense_137[0][0]
# ==================================================================================================
# Total params: 5,838
# Trainable params: 5,838
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 8343 samples, validate on 927 samples
# Epoch 1/5
# 8343/8343 [==============================] - 3s 372us/step - loss: 1.0456 - val_loss: 0.9631
# Epoch 2/5
# 8343/8343 [==============================] - 0s 50us/step - loss: 0.9433 - val_loss: 0.9585
# Epoch 3/5
# 8343/8343 [==============================] - 1s 61us/step - loss: 0.9259 - val_loss: 0.9528
# Epoch 4/5
# 8343/8343 [==============================] - 1s 61us/step - loss: 0.9153 - val_loss: 0.9550
# Epoch 5/5
# 8343/8343 [==============================] - 0s 50us/step - loss: 0.9043 - val_loss: 0.9640
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_93 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_94 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# embedding_47 (Embedding)        (None, 1, 5)         5280        input_93[0][0]
#                                                                  input_94[0][0]
# __________________________________________________________________________________________________
# flatten_93 (Flatten)            (None, 5)            0           embedding_47[0][0]
# __________________________________________________________________________________________________
# flatten_94 (Flatten)            (None, 5)            0           embedding_47[1][0]
# __________________________________________________________________________________________________
# concatenate_47 (Concatenate)    (None, 10)           0           flatten_93[0][0]
#                                                                  flatten_94[0][0]
# __________________________________________________________________________________________________
# dense_139 (Dense)               (None, 100)          1100        concatenate_47[0][0]
# __________________________________________________________________________________________________
# dense_140 (Dense)               (None, 20)           2020        dense_139[0][0]
# __________________________________________________________________________________________________
# dense_141 (Dense)               (None, 3)            63          dense_140[0][0]
# ==================================================================================================
# Total params: 8,463
# Trainable params: 8,463
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 8343 samples, validate on 927 samples
# Epoch 1/5
# 8343/8343 [==============================] - 3s 384us/step - loss: 0.9668 - val_loss: 0.9228
# Epoch 2/5
# 8343/8343 [==============================] - 1s 63us/step - loss: 0.8496 - val_loss: 0.8953
# Epoch 3/5
# 8343/8343 [==============================] - 0s 60us/step - loss: 0.7955 - val_loss: 0.9267
# Epoch 4/5
# 8343/8343 [==============================] - 0s 58us/step - loss: 0.7672 - val_loss: 0.9169
# Epoch 5/5
# 8343/8343 [==============================] - 0s 52us/step - loss: 0.7490 - val_loss: 0.9276
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_95 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_96 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# embedding_48 (Embedding)        (None, 1, 5)         1790        input_95[0][0]
#                                                                  input_96[0][0]
# __________________________________________________________________________________________________
# flatten_95 (Flatten)            (None, 5)            0           embedding_48[0][0]
# __________________________________________________________________________________________________
# flatten_96 (Flatten)            (None, 5)            0           embedding_48[1][0]
# __________________________________________________________________________________________________
# concatenate_48 (Concatenate)    (None, 10)           0           flatten_95[0][0]
#                                                                  flatten_96[0][0]
# __________________________________________________________________________________________________
# dense_142 (Dense)               (None, 100)          1100        concatenate_48[0][0]
# __________________________________________________________________________________________________
# dense_143 (Dense)               (None, 20)           2020        dense_142[0][0]
# __________________________________________________________________________________________________
# dense_144 (Dense)               (None, 3)            63          dense_143[0][0]
# ==================================================================================================
# Total params: 4,973
# Trainable params: 4,973
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 4230 samples, validate on 471 samples
# Epoch 1/5
# 4230/4230 [==============================] - 3s 694us/step - loss: 1.0516 - val_loss: 1.0366
# Epoch 2/5
# 4230/4230 [==============================] - 0s 47us/step - loss: 0.9697 - val_loss: 0.9328
# Epoch 3/5
# 4230/4230 [==============================] - 0s 55us/step - loss: 0.8525 - val_loss: 0.9172
# Epoch 4/5
# 4230/4230 [==============================] - 0s 57us/step - loss: 0.8138 - val_loss: 0.9289
# Epoch 5/5
# 4230/4230 [==============================] - 0s 52us/step - loss: 0.7919 - val_loss: 0.9331
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_97 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_98 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# embedding_49 (Embedding)        (None, 1, 5)         4390        input_97[0][0]
#                                                                  input_98[0][0]
# __________________________________________________________________________________________________
# flatten_97 (Flatten)            (None, 5)            0           embedding_49[0][0]
# __________________________________________________________________________________________________
# flatten_98 (Flatten)            (None, 5)            0           embedding_49[1][0]
# __________________________________________________________________________________________________
# concatenate_49 (Concatenate)    (None, 10)           0           flatten_97[0][0]
#                                                                  flatten_98[0][0]
# __________________________________________________________________________________________________
# dense_145 (Dense)               (None, 100)          1100        concatenate_49[0][0]
# __________________________________________________________________________________________________
# dense_146 (Dense)               (None, 20)           2020        dense_145[0][0]
# __________________________________________________________________________________________________
# dense_147 (Dense)               (None, 3)            63          dense_146[0][0]
# ==================================================================================================
# Total params: 7,573
# Trainable params: 7,573
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 4230 samples, validate on 471 samples
# Epoch 1/5
# 4230/4230 [==============================] - 3s 701us/step - loss: 1.0107 - val_loss: 0.9560
# Epoch 2/5
# 4230/4230 [==============================] - 0s 48us/step - loss: 0.9240 - val_loss: 0.9019
# Epoch 3/5
# 4230/4230 [==============================] - 0s 48us/step - loss: 0.8260 - val_loss: 0.8982
# Epoch 4/5
# 4230/4230 [==============================] - 0s 49us/step - loss: 0.7675 - val_loss: 0.9261
# Epoch 5/5
# 4230/4230 [==============================] - 0s 60us/step - loss: 0.7279 - val_loss: 0.9454
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_99 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_100 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_50 (Embedding)        (None, 1, 5)         1790        input_99[0][0]
#                                                                  input_100[0][0]
# __________________________________________________________________________________________________
# flatten_99 (Flatten)            (None, 5)            0           embedding_50[0][0]
# __________________________________________________________________________________________________
# flatten_100 (Flatten)           (None, 5)            0           embedding_50[1][0]
# __________________________________________________________________________________________________
# concatenate_50 (Concatenate)    (None, 10)           0           flatten_99[0][0]
#                                                                  flatten_100[0][0]
# ...
#                                                                  flatten_122[0][0]
# __________________________________________________________________________________________________
# dense_181 (Dense)               (None, 100)          1100        concatenate_61[0][0]
# __________________________________________________________________________________________________
# dense_182 (Dense)               (None, 20)           2020        dense_181[0][0]
# __________________________________________________________________________________________________
# dense_183 (Dense)               (None, 3)            63          dense_182[0][0]
# ==================================================================================================
# Total params: 6,308
# Trainable params: 6,308
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 1382 samples, validate on 154 samples
# Epoch 1/5
# 1382/1382 [==============================] - 3s 2ms/step - loss: 1.0538 - val_loss: 0.9840
# Epoch 2/5
# 1382/1382 [==============================] - 0s 75us/step - loss: 0.9529 - val_loss: 0.9115
# Epoch 3/5
# 1382/1382 [==============================] - 0s 63us/step - loss: 0.9215 - val_loss: 0.9009
# Epoch 4/5
# 1382/1382 [==============================] - 0s 57us/step - loss: 0.8573 - val_loss: 0.8593
# Epoch 5/5
# 1382/1382 [==============================] - 0s 56us/step - loss: 0.7212 - val_loss: 0.8463
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_123 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_124 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_62 (Embedding)        (None, 1, 5)         1035        input_123[0][0]
#                                                                  input_124[0][0]
# __________________________________________________________________________________________________
# flatten_123 (Flatten)           (None, 5)            0           embedding_62[0][0]
# __________________________________________________________________________________________________
# flatten_124 (Flatten)           (None, 5)            0           embedding_62[1][0]
# __________________________________________________________________________________________________
# concatenate_62 (Concatenate)    (None, 10)           0           flatten_123[0][0]
#                                                                  flatten_124[0][0]
# __________________________________________________________________________________________________
# dense_184 (Dense)               (None, 100)          1100        concatenate_62[0][0]
# __________________________________________________________________________________________________
# dense_185 (Dense)               (None, 20)           2020        dense_184[0][0]
# __________________________________________________________________________________________________
# dense_186 (Dense)               (None, 3)            63          dense_185[0][0]
# ==================================================================================================
# Total params: 4,218
# Trainable params: 4,218
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 1382 samples, validate on 154 samples
# Epoch 1/5
# 1382/1382 [==============================] - 3s 3ms/step - loss: 1.0971 - val_loss: 1.0926
# Epoch 2/5
# 1382/1382 [==============================] - 0s 72us/step - loss: 1.0741 - val_loss: 1.0560
# Epoch 3/5
# 1382/1382 [==============================] - 0s 67us/step - loss: 0.9781 - val_loss: 0.9452
# Epoch 4/5
# 1382/1382 [==============================] - 0s 57us/step - loss: 0.8433 - val_loss: 0.8984
# Epoch 5/5
# 1382/1382 [==============================] - 0s 57us/step - loss: 0.7774 - val_loss: 0.9095
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_125 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_126 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_63 (Embedding)        (None, 1, 5)         3105        input_125[0][0]
#                                                                  input_126[0][0]
# __________________________________________________________________________________________________
# flatten_125 (Flatten)           (None, 5)            0           embedding_63[0][0]
# __________________________________________________________________________________________________
# flatten_126 (Flatten)           (None, 5)            0           embedding_63[1][0]
# __________________________________________________________________________________________________
# concatenate_63 (Concatenate)    (None, 10)           0           flatten_125[0][0]
#                                                                  flatten_126[0][0]
# __________________________________________________________________________________________________
# dense_187 (Dense)               (None, 100)          1100        concatenate_63[0][0]
# __________________________________________________________________________________________________
# dense_188 (Dense)               (None, 20)           2020        dense_187[0][0]
# __________________________________________________________________________________________________
# dense_189 (Dense)               (None, 3)            63          dense_188[0][0]
# ==================================================================================================
# Total params: 6,288
# Trainable params: 6,288
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 1382 samples, validate on 154 samples
# Epoch 1/5
# 1382/1382 [==============================] - 4s 3ms/step - loss: 1.0290 - val_loss: 1.0051
# Epoch 2/5
# 1382/1382 [==============================] - 0s 76us/step - loss: 0.9315 - val_loss: 1.0223
# Epoch 3/5
# 1382/1382 [==============================] - 0s 68us/step - loss: 0.9134 - val_loss: 1.0111
# Epoch 4/5
# 1382/1382 [==============================] - 0s 60us/step - loss: 0.8659 - val_loss: 1.0148
# Epoch 5/5
# 1382/1382 [==============================] - 0s 59us/step - loss: 0.7263 - val_loss: 1.0889
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_127 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_128 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_64 (Embedding)        (None, 1, 5)         1035        input_127[0][0]
#                                                                  input_128[0][0]
# __________________________________________________________________________________________________
# flatten_127 (Flatten)           (None, 5)            0           embedding_64[0][0]
# __________________________________________________________________________________________________
# flatten_128 (Flatten)           (None, 5)            0           embedding_64[1][0]
# __________________________________________________________________________________________________
# concatenate_64 (Concatenate)    (None, 10)           0           flatten_127[0][0]
#                                                                  flatten_128[0][0]
# __________________________________________________________________________________________________
# dense_190 (Dense)               (None, 100)          1100        concatenate_64[0][0]
# __________________________________________________________________________________________________
# dense_191 (Dense)               (None, 20)           2020        dense_190[0][0]
# __________________________________________________________________________________________________
# dense_192 (Dense)               (None, 3)            63          dense_191[0][0]
# ==================================================================================================
# Total params: 4,218
# Trainable params: 4,218
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 1382 samples, validate on 154 samples
# Epoch 1/5
# 1382/1382 [==============================] - 4s 3ms/step - loss: 1.0949 - val_loss: 1.0910
# Epoch 2/5
# 1382/1382 [==============================] - 0s 75us/step - loss: 1.0505 - val_loss: 1.0374
# Epoch 3/5
# 1382/1382 [==============================] - 0s 68us/step - loss: 0.9179 - val_loss: 0.9754
# Epoch 4/5
# 1382/1382 [==============================] - 0s 59us/step - loss: 0.8198 - val_loss: 0.9444
# Epoch 5/5
# 1382/1382 [==============================] - 0s 57us/step - loss: 0.7726 - val_loss: 0.9469
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_129 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_130 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_65 (Embedding)        (None, 1, 5)         3080        input_129[0][0]
#                                                                  input_130[0][0]
# __________________________________________________________________________________________________
# flatten_129 (Flatten)           (None, 5)            0           embedding_65[0][0]
# __________________________________________________________________________________________________
# flatten_130 (Flatten)           (None, 5)            0           embedding_65[1][0]
# __________________________________________________________________________________________________
# concatenate_65 (Concatenate)    (None, 10)           0           flatten_129[0][0]
#                                                                  flatten_130[0][0]
# __________________________________________________________________________________________________
# dense_193 (Dense)               (None, 100)          1100        concatenate_65[0][0]
# __________________________________________________________________________________________________
# dense_194 (Dense)               (None, 20)           2020        dense_193[0][0]
# __________________________________________________________________________________________________
# dense_195 (Dense)               (None, 3)            63          dense_194[0][0]
# ==================================================================================================
# Total params: 6,263
# Trainable params: 6,263
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 1382 samples, validate on 154 samples
# Epoch 1/5
# 1382/1382 [==============================] - 4s 3ms/step - loss: 1.0442 - val_loss: 0.9869
# Epoch 2/5
# 1382/1382 [==============================] - 0s 76us/step - loss: 0.9530 - val_loss: 0.9583
# Epoch 3/5
# 1382/1382 [==============================] - 0s 67us/step - loss: 0.9299 - val_loss: 0.9535
# Epoch 4/5
# 1382/1382 [==============================] - 0s 65us/step - loss: 0.8701 - val_loss: 0.9479
# Epoch 5/5
# 1382/1382 [==============================] - 0s 59us/step - loss: 0.7287 - val_loss: 1.0029
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
print(np.average(freq, axis=1))
print(np.average(samp, axis=1))
# Out:
# [0.43490076 0.47739973 0.48421382 0.5288988  0.54019707]
# [0.4444399  0.4135832  0.41998272 0.38504393 0.37760467]

# %% [markdown]
# # Last match

# %%
def build_model(): 
    player_1 = layers.Input(shape=(1,))
    player_2 = layers.Input(shape=(1,))
    emb_layer = layers.Embedding(num_players, 5)
    player_1_embedding = emb_layer(player_1)
    player_2_embedding = emb_layer(player_2)
    player_1_flat = layers.Flatten()(player_1_embedding)
    player_2_flat = layers.Flatten()(player_2_embedding)
    cl_concat = layers.Concatenate()([player_1_flat, player_2_flat])
    cl_dense = layers.Dense(100, activation='relu')(cl_concat)
    cl_dense1 = layers.Dense(20, activation='relu')(cl_dense)
    pred = layers.Dense(2, activation="softmax")(cl_dense1)
    model = Model([player_1, player_2], pred)
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    model.summary()
    return model

# %%
freq = np.empty((5,3))
samp = np.empty((5,3))
for idx, i in enumerate(range(5)):
    freq_players = np.squeeze(players[np.argwhere(counts>i)])
    #freq_df = df[(df.player_0.isin(freq_players)) & (df.player_1.isin(freq_players))]
    freq_df = df[df.meetings>i]
    for j in range(3):
        sample_df = df.sample(len(freq_df))

        ids = pd.factorize(np.concatenate((freq_df.player_0, freq_df.player_1)))[0]
        freq_df['p1'] =  ids[:len(freq_df)]
        freq_df['p2'] = ids[len(freq_df):]
        num_players = np.max(np.concatenate((freq_df.p1.values, freq_df.p2.values))) + 1

        train_player_1, test_player_1, train_player_2,test_player_2, train_labels, test_labels = train_test_split(freq_df['p1'], freq_df['p2'], to_categorical(freq_df['last_win']), test_size=0.1)
        model = None
        model = build_model()
        history = model.fit([train_player_1, train_player_2],
                  train_labels,
                 validation_data=([test_player_1, test_player_2], test_labels),
                  epochs=5,
                  batch_size=32
                 )
        preds = model.predict([test_player_1, test_player_2])
        freq[idx,j] = precision_recall_fscore_support(np.argmax(test_labels,axis=1), np.argmax(preds, axis=1), average='macro')[2]

        ids = pd.factorize(np.concatenate((sample_df.player_0, sample_df.player_1)))[0]
        sample_df['p1'] =  ids[:len(sample_df)]
        sample_df['p2'] = ids[len(sample_df):]
        num_players = np.max(np.concatenate((sample_df.p1.values, sample_df.p2.values))) + 1

        train_player_1, test_player_1, train_player_2,test_player_2, train_labels, test_labels = train_test_split(sample_df['p1'], sample_df['p2'], to_categorical(sample_df['last_win']), test_size=0.1)
        model = None
        model = build_model()
        history = model.fit([train_player_1, train_player_2],
                  train_labels,
                 validation_data=([test_player_1, test_player_2], test_labels),
                  epochs=5,
                  batch_size=32
                 )
        preds = model.predict([test_player_1, test_player_2])
        samp[idx,j] = precision_recall_fscore_support(np.argmax(test_labels,axis=1), np.argmax(preds, axis=1), average='macro')[2]
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_131 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_132 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_66 (Embedding)        (None, 1, 5)         6935        input_131[0][0]
#                                                                  input_132[0][0]
# __________________________________________________________________________________________________
# flatten_131 (Flatten)           (None, 5)            0           embedding_66[0][0]
# __________________________________________________________________________________________________
# flatten_132 (Flatten)           (None, 5)            0           embedding_66[1][0]
# __________________________________________________________________________________________________
# concatenate_66 (Concatenate)    (None, 10)           0           flatten_131[0][0]
#                                                                  flatten_132[0][0]
# __________________________________________________________________________________________________
# dense_196 (Dense)               (None, 100)          1100        concatenate_66[0][0]
# __________________________________________________________________________________________________
# dense_197 (Dense)               (None, 20)           2020        dense_196[0][0]
# __________________________________________________________________________________________________
# dense_198 (Dense)               (None, 2)            42          dense_197[0][0]
# ==================================================================================================
# Total params: 10,097
# Trainable params: 10,097
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 23012 samples, validate on 2557 samples
# Epoch 1/5
# 23012/23012 [==============================] - 5s 219us/step - loss: 0.6389 - val_loss: 0.6059
# Epoch 2/5
# 23012/23012 [==============================] - 1s 59us/step - loss: 0.5912 - val_loss: 0.5999
# Epoch 3/5
# 23012/23012 [==============================] - 2s 68us/step - loss: 0.5802 - val_loss: 0.6023
# Epoch 4/5
# 23012/23012 [==============================] - 2s 67us/step - loss: 0.5710 - val_loss: 0.6038
# Epoch 5/5
# 23012/23012 [==============================] - 1s 60us/step - loss: 0.5615 - val_loss: 0.6055
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_133 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_134 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_67 (Embedding)        (None, 1, 5)         6935        input_133[0][0]
#                                                                  input_134[0][0]
# __________________________________________________________________________________________________
# flatten_133 (Flatten)           (None, 5)            0           embedding_67[0][0]
# __________________________________________________________________________________________________
# flatten_134 (Flatten)           (None, 5)            0           embedding_67[1][0]
# __________________________________________________________________________________________________
# concatenate_67 (Concatenate)    (None, 10)           0           flatten_133[0][0]
#                                                                  flatten_134[0][0]
# __________________________________________________________________________________________________
# dense_199 (Dense)               (None, 100)          1100        concatenate_67[0][0]
# __________________________________________________________________________________________________
# dense_200 (Dense)               (None, 20)           2020        dense_199[0][0]
# __________________________________________________________________________________________________
# dense_201 (Dense)               (None, 2)            42          dense_200[0][0]
# ==================================================================================================
# Total params: 10,097
# Trainable params: 10,097
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 23012 samples, validate on 2557 samples
# Epoch 1/5
# 23012/23012 [==============================] - 5s 224us/step - loss: 0.6338 - val_loss: 0.6101
# Epoch 2/5
# 23012/23012 [==============================] - 1s 61us/step - loss: 0.5903 - val_loss: 0.5970
# Epoch 3/5
# 23012/23012 [==============================] - 1s 65us/step - loss: 0.5793 - val_loss: 0.5990
# Epoch 4/5
# 23012/23012 [==============================] - 1s 63us/step - loss: 0.5688 - val_loss: 0.6030
# Epoch 5/5
# 23012/23012 [==============================] - 1s 64us/step - loss: 0.5590 - val_loss: 0.6023
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_135 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_136 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_68 (Embedding)        (None, 1, 5)         6935        input_135[0][0]
#                                                                  input_136[0][0]
# __________________________________________________________________________________________________
# flatten_135 (Flatten)           (None, 5)            0           embedding_68[0][0]
# __________________________________________________________________________________________________
# flatten_136 (Flatten)           (None, 5)            0           embedding_68[1][0]
# __________________________________________________________________________________________________
# concatenate_68 (Concatenate)    (None, 10)           0           flatten_135[0][0]
#                                                                  flatten_136[0][0]
# __________________________________________________________________________________________________
# dense_202 (Dense)               (None, 100)          1100        concatenate_68[0][0]
# __________________________________________________________________________________________________
# dense_203 (Dense)               (None, 20)           2020        dense_202[0][0]
# __________________________________________________________________________________________________
# dense_204 (Dense)               (None, 2)            42          dense_203[0][0]
# ==================================================================================================
# Total params: 10,097
# Trainable params: 10,097
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 23012 samples, validate on 2557 samples
# Epoch 1/5
# 23012/23012 [==============================] - 5s 224us/step - loss: 0.6318 - val_loss: 0.6030
# Epoch 2/5
# 23012/23012 [==============================] - 1s 60us/step - loss: 0.5899 - val_loss: 0.6027
# Epoch 3/5
# 23012/23012 [==============================] - 1s 61us/step - loss: 0.5806 - val_loss: 0.6035
# Epoch 4/5
# 23012/23012 [==============================] - 1s 59us/step - loss: 0.5699 - val_loss: 0.6052
# Epoch 5/5
# 23012/23012 [==============================] - 1s 60us/step - loss: 0.5606 - val_loss: 0.6119
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_137 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_138 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_69 (Embedding)        (None, 1, 5)         6935        input_137[0][0]
#                                                                  input_138[0][0]
# __________________________________________________________________________________________________
# flatten_137 (Flatten)           (None, 5)            0           embedding_69[0][0]
# __________________________________________________________________________________________________
# flatten_138 (Flatten)           (None, 5)            0           embedding_69[1][0]
# __________________________________________________________________________________________________
# concatenate_69 (Concatenate)    (None, 10)           0           flatten_137[0][0]
#                                                                  flatten_138[0][0]
# __________________________________________________________________________________________________
# dense_205 (Dense)               (None, 100)          1100        concatenate_69[0][0]
# __________________________________________________________________________________________________
# dense_206 (Dense)               (None, 20)           2020        dense_205[0][0]
# __________________________________________________________________________________________________
# dense_207 (Dense)               (None, 2)            42          dense_206[0][0]
# ==================================================================================================
# Total params: 10,097
# Trainable params: 10,097
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 23012 samples, validate on 2557 samples
# Epoch 1/5
# 23012/23012 [==============================] - 5s 220us/step - loss: 0.6325 - val_loss: 0.5886
# Epoch 2/5
# 23012/23012 [==============================] - 1s 62us/step - loss: 0.5918 - val_loss: 0.5870
# Epoch 3/5
# 23012/23012 [==============================] - 1s 60us/step - loss: 0.5800 - val_loss: 0.5901
# Epoch 4/5
# 23012/23012 [==============================] - 1s 59us/step - loss: 0.5693 - val_loss: 0.5913
# Epoch 5/5
# 23012/23012 [==============================] - 1s 58us/step - loss: 0.5581 - val_loss: 0.5945
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_139 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_140 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_70 (Embedding)        (None, 1, 5)         6935        input_139[0][0]
#                                                                  input_140[0][0]
# __________________________________________________________________________________________________
# flatten_139 (Flatten)           (None, 5)            0           embedding_70[0][0]
# __________________________________________________________________________________________________
# flatten_140 (Flatten)           (None, 5)            0           embedding_70[1][0]
# __________________________________________________________________________________________________
# concatenate_70 (Concatenate)    (None, 10)           0           flatten_139[0][0]
#                                                                  flatten_140[0][0]
# __________________________________________________________________________________________________
# dense_208 (Dense)               (None, 100)          1100        concatenate_70[0][0]
# __________________________________________________________________________________________________
# dense_209 (Dense)               (None, 20)           2020        dense_208[0][0]
# __________________________________________________________________________________________________
# dense_210 (Dense)               (None, 2)            42          dense_209[0][0]
# ==================================================================================================
# Total params: 10,097
# Trainable params: 10,097
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 23012 samples, validate on 2557 samples
# Epoch 1/5
# 23012/23012 [==============================] - 5s 226us/step - loss: 0.6379 - val_loss: 0.5943
# Epoch 2/5
# 23012/23012 [==============================] - 1s 62us/step - loss: 0.5926 - val_loss: 0.5956
# Epoch 3/5
# 23012/23012 [==============================] - 1s 62us/step - loss: 0.5808 - val_loss: 0.5913
# Epoch 4/5
# 23012/23012 [==============================] - 1s 61us/step - loss: 0.5697 - val_loss: 0.5932
# Epoch 5/5
# 23012/23012 [==============================] - 1s 61us/step - loss: 0.5591 - val_loss: 0.6062
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_141 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_142 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_71 (Embedding)        (None, 1, 5)         6935        input_141[0][0]
#                                                                  input_142[0][0]
# __________________________________________________________________________________________________
# flatten_141 (Flatten)           (None, 5)            0           embedding_71[0][0]
# __________________________________________________________________________________________________
# flatten_142 (Flatten)           (None, 5)            0           embedding_71[1][0]
# __________________________________________________________________________________________________
# concatenate_71 (Concatenate)    (None, 10)           0           flatten_141[0][0]
#                                                                  flatten_142[0][0]
# __________________________________________________________________________________________________
# dense_211 (Dense)               (None, 100)          1100        concatenate_71[0][0]
# __________________________________________________________________________________________________
# dense_212 (Dense)               (None, 20)           2020        dense_211[0][0]
# __________________________________________________________________________________________________
# dense_213 (Dense)               (None, 2)            42          dense_212[0][0]
# ==================================================================================================
# Total params: 10,097
# Trainable params: 10,097
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 23012 samples, validate on 2557 samples
# Epoch 1/5
# 23012/23012 [==============================] - 5s 228us/step - loss: 0.6289 - val_loss: 0.6113
# Epoch 2/5
# 23012/23012 [==============================] - 1s 64us/step - loss: 0.5865 - val_loss: 0.6149
# Epoch 3/5
# 23012/23012 [==============================] - 1s 60us/step - loss: 0.5753 - val_loss: 0.6196
# Epoch 4/5
# 23012/23012 [==============================] - 1s 60us/step - loss: 0.5662 - val_loss: 0.6247
# Epoch 5/5
# 23012/23012 [==============================] - 1s 60us/step - loss: 0.5561 - val_loss: 0.6378
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_143 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_144 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_72 (Embedding)        (None, 1, 5)         2655        input_143[0][0]
#                                                                  input_144[0][0]
# __________________________________________________________________________________________________
# flatten_143 (Flatten)           (None, 5)            0           embedding_72[0][0]
# __________________________________________________________________________________________________
# flatten_144 (Flatten)           (None, 5)            0           embedding_72[1][0]
# __________________________________________________________________________________________________
# concatenate_72 (Concatenate)    (None, 10)           0           flatten_143[0][0]
#                                                                  flatten_144[0][0]
# __________________________________________________________________________________________________
# dense_214 (Dense)               (None, 100)          1100        concatenate_72[0][0]
# __________________________________________________________________________________________________
# dense_215 (Dense)               (None, 20)           2020        dense_214[0][0]
# __________________________________________________________________________________________________
# dense_216 (Dense)               (None, 2)            42          dense_215[0][0]
# ==================================================================================================
# Total params: 5,817
# Trainable params: 5,817
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 8343 samples, validate on 927 samples
# Epoch 1/5
# 8343/8343 [==============================] - 4s 524us/step - loss: 0.6142 - val_loss: 0.5466
# Epoch 2/5
# 8343/8343 [==============================] - 1s 62us/step - loss: 0.5108 - val_loss: 0.5445
# Epoch 3/5
# 8343/8343 [==============================] - 1s 62us/step - loss: 0.4961 - val_loss: 0.5452
# Epoch 4/5
# 8343/8343 [==============================] - 1s 62us/step - loss: 0.4889 - val_loss: 0.5520
# Epoch 5/5
# 8343/8343 [==============================] - 1s 61us/step - loss: 0.4829 - val_loss: 0.5556
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_145 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_146 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_73 (Embedding)        (None, 1, 5)         5335        input_145[0][0]
#                                                                  input_146[0][0]
# __________________________________________________________________________________________________
# flatten_145 (Flatten)           (None, 5)            0           embedding_73[0][0]
# __________________________________________________________________________________________________
# flatten_146 (Flatten)           (None, 5)            0           embedding_73[1][0]
# __________________________________________________________________________________________________
# concatenate_73 (Concatenate)    (None, 10)           0           flatten_145[0][0]
#                                                                  flatten_146[0][0]
# __________________________________________________________________________________________________
# dense_217 (Dense)               (None, 100)          1100        concatenate_73[0][0]
# __________________________________________________________________________________________________
# dense_218 (Dense)               (None, 20)           2020        dense_217[0][0]
# __________________________________________________________________________________________________
# dense_219 (Dense)               (None, 2)            42          dense_218[0][0]
# ==================================================================================================
# Total params: 8,497
# Trainable params: 8,497
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 8343 samples, validate on 927 samples
# Epoch 1/5
# 8343/8343 [==============================] - 5s 541us/step - loss: 0.6635 - val_loss: 0.6300
# Epoch 2/5
# 8343/8343 [==============================] - 1s 62us/step - loss: 0.5819 - val_loss: 0.6271
# Epoch 3/5
# 8343/8343 [==============================] - 1s 63us/step - loss: 0.5516 - val_loss: 0.6387
# Epoch 4/5
# 8343/8343 [==============================] - 1s 61us/step - loss: 0.5325 - val_loss: 0.6485
# Epoch 5/5
# 8343/8343 [==============================] - 1s 62us/step - loss: 0.5187 - val_loss: 0.6455
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_147 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_148 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_74 (Embedding)        (None, 1, 5)         2655        input_147[0][0]
#                                                                  input_148[0][0]
# __________________________________________________________________________________________________
# flatten_147 (Flatten)           (None, 5)            0           embedding_74[0][0]
# __________________________________________________________________________________________________
# flatten_148 (Flatten)           (None, 5)            0           embedding_74[1][0]
# __________________________________________________________________________________________________
# concatenate_74 (Concatenate)    (None, 10)           0           flatten_147[0][0]
#                                                                  flatten_148[0][0]
# __________________________________________________________________________________________________
# dense_220 (Dense)               (None, 100)          1100        concatenate_74[0][0]
# __________________________________________________________________________________________________
# dense_221 (Dense)               (None, 20)           2020        dense_220[0][0]
# __________________________________________________________________________________________________
# dense_222 (Dense)               (None, 2)            42          dense_221[0][0]
# ==================================================================================================
# Total params: 5,817
# Trainable params: 5,817
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 8343 samples, validate on 927 samples
# Epoch 1/5
# 8343/8343 [==============================] - 5s 543us/step - loss: 0.6185 - val_loss: 0.5327
# Epoch 2/5
# 8343/8343 [==============================] - 1s 63us/step - loss: 0.5136 - val_loss: 0.5226
# Epoch 3/5
# 8343/8343 [==============================] - 1s 62us/step - loss: 0.4958 - val_loss: 0.5328
# Epoch 4/5
# 8343/8343 [==============================] - 1s 62us/step - loss: 0.4852 - val_loss: 0.5346
# Epoch 5/5
# 8343/8343 [==============================] - 1s 62us/step - loss: 0.4786 - val_loss: 0.5392
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_149 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_150 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_75 (Embedding)        (None, 1, 5)         5385        input_149[0][0]
#                                                                  input_150[0][0]
# __________________________________________________________________________________________________
# flatten_149 (Flatten)           (None, 5)            0           embedding_75[0][0]
# __________________________________________________________________________________________________
# flatten_150 (Flatten)           (None, 5)            0           embedding_75[1][0]
# __________________________________________________________________________________________________
# concatenate_75 (Concatenate)    (None, 10)           0           flatten_149[0][0]
#                                                                  flatten_150[0][0]
# __________________________________________________________________________________________________
# dense_223 (Dense)               (None, 100)          1100        concatenate_75[0][0]
# __________________________________________________________________________________________________
# dense_224 (Dense)               (None, 20)           2020        dense_223[0][0]
# __________________________________________________________________________________________________
# dense_225 (Dense)               (None, 2)            42          dense_224[0][0]
# ==================================================================================================
# Total params: 8,547
# Trainable params: 8,547
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 8343 samples, validate on 927 samples
# Epoch 1/5
# 8343/8343 [==============================] - 5s 549us/step - loss: 0.6669 - val_loss: 0.6240
# Epoch 2/5
# 8343/8343 [==============================] - 1s 65us/step - loss: 0.5913 - val_loss: 0.6236
# Epoch 3/5
# 8343/8343 [==============================] - 1s 64us/step - loss: 0.5681 - val_loss: 0.6313
# Epoch 4/5
# 8343/8343 [==============================] - 1s 64us/step - loss: 0.5513 - val_loss: 0.6427
# Epoch 5/5
# 8343/8343 [==============================] - 1s 68us/step - loss: 0.5356 - val_loss: 0.6605
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_151 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_152 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_76 (Embedding)        (None, 1, 5)         2655        input_151[0][0]
#                                                                  input_152[0][0]
# __________________________________________________________________________________________________
# flatten_151 (Flatten)           (None, 5)            0           embedding_76[0][0]
# __________________________________________________________________________________________________
# flatten_152 (Flatten)           (None, 5)            0           embedding_76[1][0]
# __________________________________________________________________________________________________
# concatenate_76 (Concatenate)    (None, 10)           0           flatten_151[0][0]
#                                                                  flatten_152[0][0]
# __________________________________________________________________________________________________
# dense_226 (Dense)               (None, 100)          1100        concatenate_76[0][0]
# __________________________________________________________________________________________________
# dense_227 (Dense)               (None, 20)           2020        dense_226[0][0]
# __________________________________________________________________________________________________
# dense_228 (Dense)               (None, 2)            42          dense_227[0][0]
# ==================================================================================================
# Total params: 5,817
# Trainable params: 5,817
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 8343 samples, validate on 927 samples
# Epoch 1/5
# 8343/8343 [==============================] - 5s 572us/step - loss: 0.6160 - val_loss: 0.5535
# Epoch 2/5
# 8343/8343 [==============================] - 1s 64us/step - loss: 0.5107 - val_loss: 0.5400
# Epoch 3/5
# 8343/8343 [==============================] - 1s 64us/step - loss: 0.4960 - val_loss: 0.5423
# Epoch 4/5
# 8343/8343 [==============================] - 1s 64us/step - loss: 0.4875 - val_loss: 0.5485
# Epoch 5/5
# 8343/8343 [==============================] - 1s 64us/step - loss: 0.4794 - val_loss: 0.5575
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_153 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_154 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_77 (Embedding)        (None, 1, 5)         5380        input_153[0][0]
#                                                                  input_154[0][0]
# __________________________________________________________________________________________________
# flatten_153 (Flatten)           (None, 5)            0           embedding_77[0][0]
# __________________________________________________________________________________________________
# flatten_154 (Flatten)           (None, 5)            0           embedding_77[1][0]
# __________________________________________________________________________________________________
# concatenate_77 (Concatenate)    (None, 10)           0           flatten_153[0][0]
#                                                                  flatten_154[0][0]
# __________________________________________________________________________________________________
# dense_229 (Dense)               (None, 100)          1100        concatenate_77[0][0]
# __________________________________________________________________________________________________
# dense_230 (Dense)               (None, 20)           2020        dense_229[0][0]
# __________________________________________________________________________________________________
# dense_231 (Dense)               (None, 2)            42          dense_230[0][0]
# ==================================================================================================
# Total params: 8,542
# Trainable params: 8,542
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 8343 samples, validate on 927 samples
# Epoch 1/5
# 8343/8343 [==============================] - 5s 583us/step - loss: 0.6673 - val_loss: 0.6241
# Epoch 2/5
# 8343/8343 [==============================] - 1s 65us/step - loss: 0.5885 - val_loss: 0.6154
# Epoch 3/5
# 8343/8343 [==============================] - 1s 66us/step - loss: 0.5606 - val_loss: 0.6257
# Epoch 4/5
# 8343/8343 [==============================] - 1s 65us/step - loss: 0.5397 - val_loss: 0.6412
# Epoch 5/5
# 8343/8343 [==============================] - 1s 64us/step - loss: 0.5282 - val_loss: 0.6426
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_155 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_156 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_78 (Embedding)        (None, 1, 5)         1790        input_155[0][0]
#                                                                  input_156[0][0]
# __________________________________________________________________________________________________
# flatten_155 (Flatten)           (None, 5)            0           embedding_78[0][0]
# __________________________________________________________________________________________________
# flatten_156 (Flatten)           (None, 5)            0           embedding_78[1][0]
# __________________________________________________________________________________________________
# concatenate_78 (Concatenate)    (None, 10)           0           flatten_155[0][0]
#                                                                  flatten_156[0][0]
# __________________________________________________________________________________________________
# dense_232 (Dense)               (None, 100)          1100        concatenate_78[0][0]
# __________________________________________________________________________________________________
# dense_233 (Dense)               (None, 20)           2020        dense_232[0][0]
# __________________________________________________________________________________________________
# dense_234 (Dense)               (None, 2)            42          dense_233[0][0]
# ==================================================================================================
# Total params: 4,952
# Trainable params: 4,952
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 4230 samples, validate on 471 samples
# Epoch 1/5
# 4230/4230 [==============================] - 5s 1ms/step - loss: 0.6392 - val_loss: 0.4923
# Epoch 2/5
# 4230/4230 [==============================] - 0s 66us/step - loss: 0.4371 - val_loss: 0.4438
# Epoch 3/5
# 4230/4230 [==============================] - 0s 67us/step - loss: 0.4048 - val_loss: 0.4386
# Epoch 4/5
# 4230/4230 [==============================] - 0s 65us/step - loss: 0.3964 - val_loss: 0.4435
# Epoch 5/5
# 4230/4230 [==============================] - 0s 68us/step - loss: 0.3850 - val_loss: 0.4438
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_157 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_158 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_79 (Embedding)        (None, 1, 5)         4345        input_157[0][0]
#                                                                  input_158[0][0]
# __________________________________________________________________________________________________
# flatten_157 (Flatten)           (None, 5)            0           embedding_79[0][0]
# __________________________________________________________________________________________________
# flatten_158 (Flatten)           (None, 5)            0           embedding_79[1][0]
# __________________________________________________________________________________________________
# concatenate_79 (Concatenate)    (None, 10)           0           flatten_157[0][0]
#                                                                  flatten_158[0][0]
# __________________________________________________________________________________________________
# dense_235 (Dense)               (None, 100)          1100        concatenate_79[0][0]
# __________________________________________________________________________________________________
# dense_236 (Dense)               (None, 20)           2020        dense_235[0][0]
# __________________________________________________________________________________________________
# dense_237 (Dense)               (None, 2)            42          dense_236[0][0]
# ==================================================================================================
# Total params: 7,507
# Trainable params: 7,507
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 4230 samples, validate on 471 samples
# Epoch 1/5
# 4230/4230 [==============================] - 5s 1ms/step - loss: 0.6913 - val_loss: 0.6846
# Epoch 2/5
# 4230/4230 [==============================] - 0s 67us/step - loss: 0.6317 - val_loss: 0.6479
# Epoch 3/5
# 4230/4230 [==============================] - 0s 67us/step - loss: 0.5425 - val_loss: 0.6866
# Epoch 4/5
# 4230/4230 [==============================] - 0s 67us/step - loss: 0.4994 - val_loss: 0.7163
# Epoch 5/5
# 4230/4230 [==============================] - 0s 67us/step - loss: 0.4746 - val_loss: 0.7278
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_159 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_160 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_80 (Embedding)        (None, 1, 5)         1790        input_159[0][0]
#                                                                  input_160[0][0]
# __________________________________________________________________________________________________
# flatten_159 (Flatten)           (None, 5)            0           embedding_80[0][0]
# __________________________________________________________________________________________________
# flatten_160 (Flatten)           (None, 5)            0           embedding_80[1][0]
# __________________________________________________________________________________________________
# concatenate_80 (Concatenate)    (None, 10)           0           flatten_159[0][0]
#                                                                  flatten_160[0][0]
# __________________________________________________________________________________________________
# dense_238 (Dense)               (None, 100)          1100        concatenate_80[0][0]
# __________________________________________________________________________________________________
# ...
# embedding_91 (Embedding)        (None, 1, 5)         3040        input_181[0][0]
#                                                                  input_182[0][0]
# __________________________________________________________________________________________________
# flatten_181 (Flatten)           (None, 5)            0           embedding_91[0][0]
# __________________________________________________________________________________________________
# flatten_182 (Flatten)           (None, 5)            0           embedding_91[1][0]
# __________________________________________________________________________________________________
# concatenate_91 (Concatenate)    (None, 10)           0           flatten_181[0][0]
#                                                                  flatten_182[0][0]
# __________________________________________________________________________________________________
# dense_271 (Dense)               (None, 100)          1100        concatenate_91[0][0]
# __________________________________________________________________________________________________
# dense_272 (Dense)               (None, 20)           2020        dense_271[0][0]
# __________________________________________________________________________________________________
# dense_273 (Dense)               (None, 2)            42          dense_272[0][0]
# ==================================================================================================
# Total params: 6,202
# Trainable params: 6,202
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 1382 samples, validate on 154 samples
# Epoch 1/5
# 1382/1382 [==============================] - 5s 4ms/step - loss: 0.6931 - val_loss: 0.6910
# Epoch 2/5
# 1382/1382 [==============================] - 0s 101us/step - loss: 0.6837 - val_loss: 0.6813
# Epoch 3/5
# 1382/1382 [==============================] - 0s 84us/step - loss: 0.6257 - val_loss: 0.6690
# Epoch 4/5
# 1382/1382 [==============================] - 0s 77us/step - loss: 0.4961 - val_loss: 0.7393
# Epoch 5/5
# 1382/1382 [==============================] - 0s 77us/step - loss: 0.3998 - val_loss: 0.8530
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_183 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_184 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_92 (Embedding)        (None, 1, 5)         1035        input_183[0][0]
#                                                                  input_184[0][0]
# __________________________________________________________________________________________________
# flatten_183 (Flatten)           (None, 5)            0           embedding_92[0][0]
# __________________________________________________________________________________________________
# flatten_184 (Flatten)           (None, 5)            0           embedding_92[1][0]
# __________________________________________________________________________________________________
# concatenate_92 (Concatenate)    (None, 10)           0           flatten_183[0][0]
#                                                                  flatten_184[0][0]
# __________________________________________________________________________________________________
# dense_274 (Dense)               (None, 100)          1100        concatenate_92[0][0]
# __________________________________________________________________________________________________
# dense_275 (Dense)               (None, 20)           2020        dense_274[0][0]
# __________________________________________________________________________________________________
# dense_276 (Dense)               (None, 2)            42          dense_275[0][0]
# ==================================================================================================
# Total params: 4,197
# Trainable params: 4,197
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 1382 samples, validate on 154 samples
# Epoch 1/5
# 1382/1382 [==============================] - 5s 4ms/step - loss: 0.6928 - val_loss: 0.6924
# Epoch 2/5
# 1382/1382 [==============================] - 0s 101us/step - loss: 0.6787 - val_loss: 0.6419
# Epoch 3/5
# 1382/1382 [==============================] - 0s 80us/step - loss: 0.5305 - val_loss: 0.4214
# Epoch 4/5
# 1382/1382 [==============================] - 0s 77us/step - loss: 0.3512 - val_loss: 0.3601
# Epoch 5/5
# 1382/1382 [==============================] - 0s 78us/step - loss: 0.2952 - val_loss: 0.3564
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_185 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_186 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_93 (Embedding)        (None, 1, 5)         3280        input_185[0][0]
#                                                                  input_186[0][0]
# __________________________________________________________________________________________________
# flatten_185 (Flatten)           (None, 5)            0           embedding_93[0][0]
# __________________________________________________________________________________________________
# flatten_186 (Flatten)           (None, 5)            0           embedding_93[1][0]
# __________________________________________________________________________________________________
# concatenate_93 (Concatenate)    (None, 10)           0           flatten_185[0][0]
#                                                                  flatten_186[0][0]
# __________________________________________________________________________________________________
# dense_277 (Dense)               (None, 100)          1100        concatenate_93[0][0]
# __________________________________________________________________________________________________
# dense_278 (Dense)               (None, 20)           2020        dense_277[0][0]
# __________________________________________________________________________________________________
# dense_279 (Dense)               (None, 2)            42          dense_278[0][0]
# ==================================================================================================
# Total params: 6,442
# Trainable params: 6,442
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 1382 samples, validate on 154 samples
# Epoch 1/5
# 1382/1382 [==============================] - 5s 4ms/step - loss: 0.6930 - val_loss: 0.6936
# Epoch 2/5
# 1382/1382 [==============================] - 0s 103us/step - loss: 0.6888 - val_loss: 0.6917
# Epoch 3/5
# 1382/1382 [==============================] - 0s 84us/step - loss: 0.6670 - val_loss: 0.6798
# Epoch 4/5
# 1382/1382 [==============================] - 0s 82us/step - loss: 0.5672 - val_loss: 0.7078
# Epoch 5/5
# 1382/1382 [==============================] - 0s 78us/step - loss: 0.4375 - val_loss: 0.8072
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/marko/anaconda3/envs/news/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_187 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_188 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_94 (Embedding)        (None, 1, 5)         1035        input_187[0][0]
#                                                                  input_188[0][0]
# __________________________________________________________________________________________________
# flatten_187 (Flatten)           (None, 5)            0           embedding_94[0][0]
# __________________________________________________________________________________________________
# flatten_188 (Flatten)           (None, 5)            0           embedding_94[1][0]
# __________________________________________________________________________________________________
# concatenate_94 (Concatenate)    (None, 10)           0           flatten_187[0][0]
#                                                                  flatten_188[0][0]
# __________________________________________________________________________________________________
# dense_280 (Dense)               (None, 100)          1100        concatenate_94[0][0]
# __________________________________________________________________________________________________
# dense_281 (Dense)               (None, 20)           2020        dense_280[0][0]
# __________________________________________________________________________________________________
# dense_282 (Dense)               (None, 2)            42          dense_281[0][0]
# ==================================================================================================
# Total params: 4,197
# Trainable params: 4,197
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 1382 samples, validate on 154 samples
# Epoch 1/5
# 1382/1382 [==============================] - 5s 4ms/step - loss: 0.6924 - val_loss: 0.6873
# Epoch 2/5
# 1382/1382 [==============================] - 0s 102us/step - loss: 0.6679 - val_loss: 0.6191
# Epoch 3/5
# 1382/1382 [==============================] - 0s 86us/step - loss: 0.4999 - val_loss: 0.4216
# Epoch 4/5
# 1382/1382 [==============================] - 0s 79us/step - loss: 0.3348 - val_loss: 0.3906
# Epoch 5/5
# 1382/1382 [==============================] - 0s 77us/step - loss: 0.2901 - val_loss: 0.3890
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_189 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_190 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_95 (Embedding)        (None, 1, 5)         3150        input_189[0][0]
#                                                                  input_190[0][0]
# __________________________________________________________________________________________________
# flatten_189 (Flatten)           (None, 5)            0           embedding_95[0][0]
# __________________________________________________________________________________________________
# flatten_190 (Flatten)           (None, 5)            0           embedding_95[1][0]
# __________________________________________________________________________________________________
# concatenate_95 (Concatenate)    (None, 10)           0           flatten_189[0][0]
#                                                                  flatten_190[0][0]
# __________________________________________________________________________________________________
# dense_283 (Dense)               (None, 100)          1100        concatenate_95[0][0]
# __________________________________________________________________________________________________
# dense_284 (Dense)               (None, 20)           2020        dense_283[0][0]
# __________________________________________________________________________________________________
# dense_285 (Dense)               (None, 2)            42          dense_284[0][0]
# ==================================================================================================
# Total params: 6,312
# Trainable params: 6,312
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 1382 samples, validate on 154 samples
# Epoch 1/5
# 1382/1382 [==============================] - 5s 4ms/step - loss: 0.6924 - val_loss: 0.6924
# Epoch 2/5
# 1382/1382 [==============================] - 0s 90us/step - loss: 0.6840 - val_loss: 0.6860
# Epoch 3/5
# 1382/1382 [==============================] - 0s 87us/step - loss: 0.6327 - val_loss: 0.6736
# Epoch 4/5
# 1382/1382 [==============================] - 0s 80us/step - loss: 0.5074 - val_loss: 0.6690
# Epoch 5/5
# 1382/1382 [==============================] - 0s 104us/step - loss: 0.4041 - val_loss: 0.7307

# %%
print(np.average(freq, axis=1))
print(np.average(samp, axis=1))
# Out:
# [0.67593479 0.73349855 0.79459114 0.82184588 0.84305607]
# [0.67492168 0.6421452  0.62369951 0.64063955 0.57209557]

# %% [markdown]
# # Visualize
